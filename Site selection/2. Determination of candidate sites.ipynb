# %%
# Ploting and data manage
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import folium
import seaborn as sns
import pandas as pd
from matplotlib import colors

# Machine learning algorithms and metrics
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
#from sklearn.metrics import pairwise_distances, silhoutte_score

import matplotlib.ticker as mticker
from sklearn.metrics import silhouette_score
 
#ax1.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import geodataframes
# 1) **Boundaries**: Districts of Quebec city.
# 2) **Spots**: points containing Heart Attack events relevant information.

# %%
boundaries = gpd.read_file("boundaries.gpkg") 
boundaries.head()
# Out:
#                            district  \
# 0                      Les Rivières
# 1            La Haute-Saint-Charles
# 2                  La Cité-Limoilou
# 3                      Charlesbourg
# 4  Sainte-Foy - Sillery - Cap-Rouge
#
#                                             geometry
# 0  MULTIPOLYGON (((-71.26261 46.83542, -71.26082 ...
# 1  MULTIPOLYGON (((-71.40996 46.95956, -71.40973 ...
# 2  MULTIPOLYGON (((-71.26082 46.83348, -71.26261 ...
# 3  MULTIPOLYGON (((-71.32408 46.94312, -71.3239 4...
# 4  MULTIPOLYGON (((-71.49475 46.80328, -71.49472 ...

# %%
spots      = gpd.read_file('spots.gpkg')
spots.head()
# Out:
#    age  weight     income disease  events      district  \
# 0   60      73  52.134220     AST       3  Les Rivières
# 1   67      65  57.211902     DBT       2  Les Rivières
# 2   62      72  42.991846     AST       2  Les Rivières
# 3   72      58  59.658490     AST       2  Les Rivières
# 4   58      75  47.622527     AST       1  Les Rivières
#
#                      geometry
# 0  POINT (-71.27628 46.82711)
# 1  POINT (-71.31865 46.84529)
# 2  POINT (-71.32006 46.79838)
# 3  POINT (-71.29996 46.82849)
# 4  POINT (-71.33742 46.82991)

# %% [markdown]
# ### Exploratory analysis

# %%
plt.figure(figsize=(18,4))

# AGE
plt.subplot(1,5,1)
plt.hist(spots['age'], bins=15, edgecolor="black")
plt.title('AGE')
plt.xlabel('YEARS')
plt.grid(alpha=0.3)

# WEIGHT
plt.subplot(1,5,2)
plt.hist(spots['weight'], bins=15, edgecolor="black")
plt.title('WEIGHT')
plt.xlabel('KG')
plt.grid(alpha=0.3)

# INCOME
plt.subplot(1,5,3)
plt.hist(spots['income'], bins=15, edgecolor="black")
plt.title('INCOME')
plt.xlabel('$ (Thousands)')
plt.grid(alpha=0.3)

# ILLNESS PIE
plt.subplot(1,5,4)

counts = spots['disease'].value_counts()

plt.pie(
    counts.values,
    labels=counts.index,
    autopct='%1.1f%%',
    startangle=90,
    textprops={'fontsize':8}
)

plt.title('ILLNESS')
plt.axis('equal')

# EVENTS
plt.subplot(1,5,5)
plt.hist(spots['events'], bins=10, edgecolor="black")
plt.title('HEART ATTACKS')
plt.xlabel('COUNT')
plt.grid(alpha=0.3)

# spacing
plt.tight_layout(pad=2)

plt.show()

# %% [markdown]
# 1) **AGE**: It's concentrated at older ages, with a long tail extending towards lower ages, aparently following a log-normal behavior.
# 2) **WEIGHT**: It's center around 70kg, resembling a normal distribution, with tails extending about 20kg away from the mean.
# 3) **INCOME**: It's concentrared about $50K, showing positive skewness, with a tial extending to nearly 100k dollars.
# 4) **ILLNESS**: It shows **Diabetis (DBT)** and **Asthma (AST)** as the dominant diseases with nearly 65% of the population suffering from them, and **Coronary artery disease (CAD)** and **Hypertension (HYP)** as less frequent, with a substantial fraction having neither (~20%).
# 5) **HEART ATTACKS**: HAs show skewness toward lower values, ranging from 1 to 13.

# %% [markdown]
# ## Heart attack spatial distribution

# %%
map_quebec = folium.Map(location=[46.766429, -71.289947], zoom_start=10.5)

# Load city boundaries
folium.GeoJson(
    boundaries,
    name="Quebec districts",
    style_function=lambda x: {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.3
    },
     tooltip=folium.GeoJsonTooltip(fields=["district"])
).add_to(map_quebec)

# Load the point layer
for idx, row in spots.iterrows():

    radius = np.sqrt(row["events"]) * 3.5

    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],

        radius=radius,

        color=None,              # sin borde negro
        weight=0,

        fill=True,
        fill_color="crimson",
        fill_opacity=0.7,

        tooltip=(
            f"Events: {row['events']}<br>"
            f"Age: {row['age']}<br>"
            f"Disease: {row['disease']}<br>"
            f"Weight: {row['weight']}"
        )

    ).add_to(map_quebec)

# Mostrar mapa
map_quebec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5303c14b279c173afbdc0537ba9d6de3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5303c14b279c173afbdc0537ba9d6de3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5303c14b279c173afbdc0537ba9d6de3 = L.map(
#                 &quot;map_5303c14b279c173afbdc0537ba9d6de3&quot;,
#                 {
#                     center: [46.766429, -71.289947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aadf3148007753f02da9c4a0b5add497 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aadf3148007753f02da9c4a0b5add497.addTo(map_5303c14b279c173afbdc0537ba9d6de3);
#
#
#         function geo_json_f2ea2e5097897e378f7911fa8047e849_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f2ea2e5097897e378f7911fa8047e849_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f2ea2e5097897e378f7911fa8047e849 = L.geoJson(null, {
#                 onEachFeature: geo_json_f2ea2e5097897e378f7911fa8047e849_onEachFeature,
#
#                 style: geo_json_f2ea2e5097897e378f7911fa8047e849_styler,
#         });
#
#         function geo_json_f2ea2e5097897e378f7911fa8047e849_add (data) {
#             geo_json_f2ea2e5097897e378f7911fa8047e849
#                 .addData(data);
#         }
#             geo_json_f2ea2e5097897e378f7911fa8047e849_add({&quot;bbox&quot;: [-71.54907665787805, 46.57289770674742, -70.99443659925102, 46.98073853601561], &quot;features&quot;: [{&quot;bbox&quot;: [-71.3640099746626, 46.78926190281846, -71.23925059380927, 46.870147674874936], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-71.2626065565269, 46.83542034941454], [-71.26081690277802, 46.833477873107775], [-71.25969522260063, 46.83224268973096], [-71.2576849341868, 46.830081223147445], [-71.25537222528426, 46.82756050386159], [-71.25512013120503, 46.827295861724465], [-71.2547924586023, 46.82698705300764], [-71.25443325649864, 46.826659376629706], [-71.25411190105261, 46.82640098302086], [-71.25372114345839, 46.826148930888635], [-71.25345021248471, 46.825985092901995], [-71.25316028330226, 46.82583383808063], [-71.25280109406819, 46.82565740769905], [-71.25236629646865, 46.82546205475848], [-71.2516983356173, 46.8251847659891], [-71.25033086704539, 46.82463651319182], [-71.24891922245564, 46.82405678026918], [-71.24809375197594, 46.82373536967767], [-71.24735011852155, 46.823426590720246], [-71.24691530181235, 46.82325014860015], [-71.24666951532251, 46.82314302023418], [-71.24638597675005, 46.823004383890314], [-71.24600783910658, 46.82279011662606], [-71.2457242902449, 46.82259473283265], [-71.24555414863082, 46.82246240611565], [-71.2453020229997, 46.82225447917427], [-71.24485465897129, 46.82187633906118], [-71.24460253935698, 46.82166840668679], [-71.2444008982987, 46.82152347077509], [-71.24412365612963, 46.82134072032484], [-71.24356277534811, 46.82101933492662], [-71.2432602815182, 46.8208617671828], [-71.24286960747776, 46.8206916389616], [-71.24239697447396, 46.820521502273664], [-71.24182349160968, 46.82035762449515], [-71.24106730011252, 46.82018750759743], [-71.24030477132074, 46.820042572137865], [-71.23938783309684, 46.81987139674523], [-71.23928123505092, 46.819211726498004], [-71.23925059380927, 46.81891192861682], [-71.23927511858294, 46.81858155763193], [-71.23934235959835, 46.818171666983154], [-71.23955650718742, 46.81760878441054], [-71.23984407997476, 46.817113216361676], [-71.2402662262937, 46.816568716024115], [-71.2406822115921, 46.81616495380483], [-71.24112884211635, 46.81584680393318], [-71.2414898268795, 46.81561430356187], [-71.24190581559613, 46.81540018421779], [-71.24248095671115, 46.815204403953054], [-71.2433435749929, 46.815002530382344], [-71.24488528331398, 46.81484346374573], [-71.24557665213145, 46.81485565954742], [-71.2462251333793, 46.81492908041409], [-71.2467819211501, 46.814965789109095], [-71.24740594492056, 46.8149413495884], [-71.24795043615194, 46.8148556660258], [-71.24844601251893, 46.814714964154966], [-71.2491

# %% [markdown]
# ## Finding candidate locations
# To find the set of candidate spots to build hospitals we will:
# 1) Find clusters using KMeans
# 2) Use the weighted centroids as potential candidates using the number of HA events as weighting factor

# %%
# Reproject
spots_qc = spots.to_crs(32198)

X = spots_qc.geometry.x
Y = spots_qc.geometry.y

coords = np.vstack([X, Y]).T

K_range = range(2, 15)  # silhouette does not work with K=1

inertias = []
silhouettes = []

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(coords)
    
    inertias.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(coords, labels))

# ---- FIGURA ----
fig, ax1 = plt.subplots(figsize=(8,5))

# Elbow (inertia)
ax1.plot(K_range, inertias, marker='o', label='Inertia (SSE)')
ax1.set_xlabel("Number of clusters (K)")
ax1.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))
ax1.set_ylabel("Inertia (SSE)", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.grid(True, alpha=0.3)

# Silhouette en segundo eje
ax2 = ax1.twinx()
ax2.bar(K_range, silhouettes, alpha=0.3, color='tab:orange', label='Silhouette')
ax2.set_ylabel("Silhouette Score", color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title("Elbow Method + Silhouette Score")
plt.show()

# %% [markdown]
# Nor the elbow method neither the silhouette bars are visually conclusive.
#
# ### Second derivative method.
# We compute the 2nd derivative and evaluate at 0, which will give is the break point where adding more hospitals do not change the curvature significantly.

# %%
import numpy as np

inertias = np.array(inertias)

# 1st deriative
d1 = np.diff(inertias)

# 2nd derivative
d2 = np.diff(d1)

# maximum curvature
k_elbow = np.argmax(-d2) + 2  

print("K elbow:", k_elbow)
# Out:
# K elbow: 12

# %% [markdown]
# ### Silhouette score
# The highest silhouette is associated to the optimal number of clusters.

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

scores = []

K_range = range(2, 15)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(coords)
    
    score = silhouette_score(coords, labels)
    scores.append(score)

best_k = K_range[np.argmax(scores)]
print("best K:", best_k)
# Out:
# best K: 7

# %% [markdown]
# Both methods fail to converge to a clear agreement, suggesting that the data do not naturally form distinct clusters. The silhouette bars do not exhibit a significantly dominant peak, and the elbow method does not reveal a well-defined inflection point. Given this ambiguity, and in order to maximice the number of candidate sites, we select the largest value suggested by both approaches (k=12).

# %%
n_clusters = 12
kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
spots_qc["cluster"] = kmeans.fit_predict(coords)

# %%
# Cluster colors
colormap = plt.colormaps["tab10"]

# Reproject back to WGS84
pots_map = spots_qc.to_crs(4326)

# Drawing the map
map_quebec = folium.Map(location=[46.766429, -71.289947], zoom_start=10)

# Load city boundaries
folium.GeoJson(
    boundaries,
    name="Límites Quebec",
    style_function=lambda x: {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.3
    },
     tooltip=folium.GeoJsonTooltip(fields=["district"])
).add_to(map_quebec)

# Load heart attack events
for idx, row in pots_map.iterrows():

    rad = np.sqrt(row["events"]) * 3
    
    cluster = row["cluster"]

    # ruido (-1) en negro
    if cluster == -1:
        color = "black"
    else:
        color = colors.rgb2hex(colormap(cluster % n_clusters))

    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],

        radius=rad,

        color=color,
        weight=1,

        fill=True,
        fill_color=color,
        fill_opacity=0.7,

        tooltip=(
            f"Cluster: {cluster}<br>"
            f"Events: {row['events']}<br>"
            f"Age: {row['age']}<br>"
            f"Disease: {row['disease']}<br>"
            f"Weight: {row['weight']}"
        )
    ).add_to(map_quebec)


map_quebec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d39d3efa70e5b1d669bcecfafb72340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d39d3efa70e5b1d669bcecfafb72340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d39d3efa70e5b1d669bcecfafb72340 = L.map(
#                 &quot;map_6d39d3efa70e5b1d669bcecfafb72340&quot;,
#                 {
#                     center: [46.766429, -71.289947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_947dc84d8266b7a330e47bcfc4996338 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_947dc84d8266b7a330e47bcfc4996338.addTo(map_6d39d3efa70e5b1d669bcecfafb72340);
#
#
#         function geo_json_9a0b2d69dc873136a3a749517d792048_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9a0b2d69dc873136a3a749517d792048_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9a0b2d69dc873136a3a749517d792048 = L.geoJson(null, {
#                 onEachFeature: geo_json_9a0b2d69dc873136a3a749517d792048_onEachFeature,
#
#                 style: geo_json_9a0b2d69dc873136a3a749517d792048_styler,
#         });
#
#         function geo_json_9a0b2d69dc873136a3a749517d792048_add (data) {
#             geo_json_9a0b2d69dc873136a3a749517d792048
#                 .addData(data);
#         }
#             geo_json_9a0b2d69dc873136a3a749517d792048_add({&quot;bbox&quot;: [-71.54907665787805, 46.57289770674742, -70.99443659925102, 46.98073853601561], &quot;features&quot;: [{&quot;bbox&quot;: [-71.3640099746626, 46.78926190281846, -71.23925059380927, 46.870147674874936], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-71.2626065565269, 46.83542034941454], [-71.26081690277802, 46.833477873107775], [-71.25969522260063, 46.83224268973096], [-71.2576849341868, 46.830081223147445], [-71.25537222528426, 46.82756050386159], [-71.25512013120503, 46.827295861724465], [-71.2547924586023, 46.82698705300764], [-71.25443325649864, 46.826659376629706], [-71.25411190105261, 46.82640098302086], [-71.25372114345839, 46.826148930888635], [-71.25345021248471, 46.825985092901995], [-71.25316028330226, 46.82583383808063], [-71.25280109406819, 46.82565740769905], [-71.25236629646865, 46.82546205475848], [-71.2516983356173, 46.8251847659891], [-71.25033086704539, 46.82463651319182], [-71.24891922245564, 46.82405678026918], [-71.24809375197594, 46.82373536967767], [-71.24735011852155, 46.823426590720246], [-71.24691530181235, 46.82325014860015], [-71.24666951532251, 46.82314302023418], [-71.24638597675005, 46.823004383890314], [-71.24600783910658, 46.82279011662606], [-71.2457242902449, 46.82259473283265], [-71.24555414863082, 46.82246240611565], [-71.2453020229997, 46.82225447917427], [-71.24485465897129, 46.82187633906118], [-71.24460253935698, 46.82166840668679], [-71.2444008982987, 46.82152347077509], [-71.24412365612963, 46.82134072032484], [-71.24356277534811, 46.82101933492662], [-71.2432602815182, 46.8208617671828], [-71.24286960747776, 46.8206916389616], [-71.24239697447396, 46.820521502273664], [-71.24182349160968, 46.82035762449515], [-71.24106730011252, 46.82018750759743], [-71.24030477132074, 46.820042572137865], [-71.23938783309684, 46.81987139674523], [-71.23928123505092, 46.819211726498004], [-71.23925059380927, 46.81891192861682], [-71.23927511858294, 46.81858155763193], [-71.23934235959835, 46.818171666983154], [-71.23955650718742, 46.81760878441054], [-71.23984407997476, 46.817113216361676], [-71.2402662262937, 46.816568716024115], [-71.2406822115921, 46.81616495380483], [-71.24112884211635, 46.81584680393318], [-71.2414898268795, 46.81561430356187], [-71.24190581559613, 46.81540018421779], [-71.24248095671115, 46.815204403953054], [-71.2433435749929, 46.815002530382344], [-71.24488528331398, 46.81484346374573], [-71.24557665213145, 46.81485565954742], [-71.2462251333793, 46.81492908041409], [-71.2467819211501, 46.814965789109095], [-71.24740594492056, 46.8149413495884], [-71.24795043615194, 46.8148556660258], [-71.24844601251893, 46.814714964154966], [-71.249106

# %% [markdown]
# ## Determining candidate locations
# Once clusters are known we will determine hospitals' candidate locations by computing the weighted centroid of each cluster using the number of HA events.
#
# $$
# X = \frac{\sum_i x_i \cdot n_i}{\sum_i n_i} \ \ \ \ \ Y = \frac{\sum_i y_i \cdot n_i}{\sum_i n_i}
# $$

# %%
import numpy as np

def weighted_centroid(group):
    n = group["events"]
    
    lat = np.average(group.geometry.y, weights=n)
    lon = np.average(group.geometry.x, weights=n)
    
    return pd.Series({"latitude": lat, "longitude": lon})

centroids = pots_map.groupby("cluster").apply(weighted_centroid)

# %%
centroids.to_csv('candidate_spots.csv', index=False)

# %%
# Cluster colors
colormap = plt.colormaps["tab10"]

# Drawing the map
map_quebec = folium.Map(location=[46.766429, -71.289947], zoom_start=10)

# Load city boundaries
folium.GeoJson(
    boundaries,
    name="Límites Quebec",
    style_function=lambda x: {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.3
    },
     tooltip=folium.GeoJsonTooltip(fields=["district"])
).add_to(map_quebec)

# Load heart attack events
for idx, row in pots_map.iterrows():

    rad = np.sqrt(row["events"]) * 3
    
    cluster = row["cluster"]

    # ruido (-1) en negro
    if cluster == -1:
        color = "black"
    else:
        color = colors.rgb2hex(colormap(cluster % n_clusters))

    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],

        radius=rad,

        color=color,
        weight=1,

        fill=True,
        fill_color=color,
        fill_opacity=0.7,

        tooltip=(
            f"Cluster: {cluster}<br>"
            f"Events: {row['events']}<br>"
            f"Age: {row['age']}<br>"
            f"Disease: {row['disease']}<br>"
            f"Weight: {row['weight']}"
        )
    ).add_to(map_quebec)

# Load candidate locations
for idx, row in centroids.iterrows():
    
    folium.Marker(
        location=[row["latitude"], row["longitude"]],
        icon=folium.Icon(color="green", icon="plus-sign", prefix="glyphicon"),
        tooltip=f"Candidate Hospital (Cluster {idx})"
    ).add_to(map_quebec)

map_quebec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50e44f9d63a9d8e1814c27d7a524cb94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50e44f9d63a9d8e1814c27d7a524cb94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50e44f9d63a9d8e1814c27d7a524cb94 = L.map(
#                 &quot;map_50e44f9d63a9d8e1814c27d7a524cb94&quot;,
#                 {
#                     center: [46.766429, -71.289947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fe3adf6102b55f3b5f344fab16cf45b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1fe3adf6102b55f3b5f344fab16cf45b.addTo(map_50e44f9d63a9d8e1814c27d7a524cb94);
#
#
#         function geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9 = L.geoJson(null, {
#                 onEachFeature: geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_onEachFeature,
#
#                 style: geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_styler,
#         });
#
#         function geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_add (data) {
#             geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9
#                 .addData(data);
#         }
#             geo_json_d9a0680ee71e61f14ee3b39b4aa21dd9_add({&quot;bbox&quot;: [-71.54907665787805, 46.57289770674742, -70.99443659925102, 46.98073853601561], &quot;features&quot;: [{&quot;bbox&quot;: [-71.3640099746626, 46.78926190281846, -71.23925059380927, 46.870147674874936], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-71.2626065565269, 46.83542034941454], [-71.26081690277802, 46.833477873107775], [-71.25969522260063, 46.83224268973096], [-71.2576849341868, 46.830081223147445], [-71.25537222528426, 46.82756050386159], [-71.25512013120503, 46.827295861724465], [-71.2547924586023, 46.82698705300764], [-71.25443325649864, 46.826659376629706], [-71.25411190105261, 46.82640098302086], [-71.25372114345839, 46.826148930888635], [-71.25345021248471, 46.825985092901995], [-71.25316028330226, 46.82583383808063], [-71.25280109406819, 46.82565740769905], [-71.25236629646865, 46.82546205475848], [-71.2516983356173, 46.8251847659891], [-71.25033086704539, 46.82463651319182], [-71.24891922245564, 46.82405678026918], [-71.24809375197594, 46.82373536967767], [-71.24735011852155, 46.823426590720246], [-71.24691530181235, 46.82325014860015], [-71.24666951532251, 46.82314302023418], [-71.24638597675005, 46.823004383890314], [-71.24600783910658, 46.82279011662606], [-71.2457242902449, 46.82259473283265], [-71.24555414863082, 46.82246240611565], [-71.2453020229997, 46.82225447917427], [-71.24485465897129, 46.82187633906118], [-71.24460253935698, 46.82166840668679], [-71.2444008982987, 46.82152347077509], [-71.24412365612963, 46.82134072032484], [-71.24356277534811, 46.82101933492662], [-71.2432602815182, 46.8208617671828], [-71.24286960747776, 46.8206916389616], [-71.24239697447396, 46.820521502273664], [-71.24182349160968, 46.82035762449515], [-71.24106730011252, 46.82018750759743], [-71.24030477132074, 46.820042572137865], [-71.23938783309684, 46.81987139674523], [-71.23928123505092, 46.819211726498004], [-71.23925059380927, 46.81891192861682], [-71.23927511858294, 46.81858155763193], [-71.23934235959835, 46.818171666983154], [-71.23955650718742, 46.81760878441054], [-71.23984407997476, 46.817113216361676], [-71.2402662262937, 46.816568716024115], [-71.2406822115921, 46.81616495380483], [-71.24112884211635, 46.81584680393318], [-71.2414898268795, 46.81561430356187], [-71.24190581559613, 46.81540018421779], [-71.24248095671115, 46.815204403953054], [-71.2433435749929, 46.815002530382344], [-71.24488528331398, 46.81484346374573], [-71.24557665213145, 46.81485565954742], [-71.2462251333793, 46.81492908041409], [-71.2467819211501, 46.814965789109095], [-71.24740594492056, 46.8149413495884], [-71.24795043615194, 46.8148556660258], [-71.24844601251893, 46.814714964154966], [-71.249106
